# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from prophet import Prophet
from sklearn.metrics import mean_absolute_percentage_error
import numpy as np

# %%
data = pd.read_excel(r"C:\Users\GS0864\Downloads\Pizza_Sale.xlsx")

# %%
data.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity           order_date  \
# 0         1         1     hawaiian_m         1  2015-01-01 00:00:00
# 1         2         2  classic_dlx_m         1  2015-01-01 00:00:00
# 2         3         2  five_cheese_l         1  2015-01-01 00:00:00
# 3         4         2    ital_supr_l         1  2015-01-01 00:00:00
# 4         5         2     mexicana_m         1  2015-01-01 00:00:00
#
#   order_time  unit_price  total_price pizza_size pizza_category  \
# 0   11:38:36       13.25        13.25          M        Classic
# 1   11:57:40       16.00        16.00          M        Classic
# 2   11:57:40       18.50        18.50          L         Veggie
# 3   11:57:40       20.75        20.75          L        Supreme
# 4   11:57:40       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48604 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48613 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48597 non-null  object
#  10  pizza_ingredients  48607 non-null  object
#  11  pizza_name         48613 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
data.isnull().sum()
# Out:
# pizza_id              0
# order_id              0
# pizza_name_id        16
# quantity              0
# order_date            0
# order_time            0
# unit_price            0
# total_price           7
# pizza_size            0
# pizza_category       23
# pizza_ingredients    13
# pizza_name            7
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
#changing order date into datetime format

data["order_date"]=pd.to_datetime(data["order_date"],errors="coerce")

# %%
#feature engineering

data[["order_hour","order_day","order_month","order_week"]] = pd.DataFrame({
    "order_hour": data["order_date"].dt.hour,
    "order_day": data["order_date"].dt.day,
    "order_month": data["order_date"].dt.month,
    "order_week": data["order_date"].dt.isocalendar().week
})

# %%
data.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0         1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1         2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2         3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3         4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4         5         2     mexicana_m         1 2015-01-01   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name  order_hour  order_day  order_month  order_week
# 0         The Hawaiian Pizza           0          1            1           1
# 1   The Classic Deluxe Pizza           0          1            1           1
# 2      The Five Cheese Pizza           0          1            1           1
# 3  The Italian Supreme Pizza           0          1            1           1
# 4         The Mexicana Pizza           0          1            1           1

# %%
data["order_day"].value_counts()
# Out:
# order_day
# 15    1844
# 27    1763
# 7     1736
# 2     1695
# 9     1695
# 12    1680
# 5     1658
# 4     1658
# 6     1654
# 20    1650
# 17    1649
# 14    1643
# 13    1643
# 11    1614
# 16    1609
# 8     1599
# 23    1595
# 3     1595
# 18    1589
# 1     1584
# 21    1560
# 24    1546
# 26    1504
# 22    1484
# 19    1463
# 28    1450
# 30    1439
# 29    1361
# 10    1353
# 25    1245
# 31     996
# Name: count, dtype: int64

# %%
# Ingredient Data

df= pd.read_excel(r"C:\Users\GS0864\Downloads\Pizza_ingredients.xlsx")

# %%
df.head()
# Out:
#   pizza_name_id                  pizza_name  pizza_ingredients  \
# 0     bbq_ckn_l  The Barbecue Chicken Pizza  Barbecued Chicken
# 1     bbq_ckn_l  The Barbecue Chicken Pizza        Red Peppers
# 2     bbq_ckn_l  The Barbecue Chicken Pizza      Green Peppers
# 3     bbq_ckn_l  The Barbecue Chicken Pizza           Tomatoes
# 4     bbq_ckn_l  The Barbecue Chicken Pizza         Red Onions
#
#    Items_Qty_In_Grams
# 0                40.0
# 1                15.0
# 2                20.0
# 3                30.0
# 4                60.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 518 entries, 0 to 517
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pizza_name_id       518 non-null    object
#  1   pizza_name          518 non-null    object
#  2   pizza_ingredients   518 non-null    object
#  3   Items_Qty_In_Grams  514 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 16.3+ KB

# %%
df.isnull().sum()
# Out:
# pizza_name_id         0
# pizza_name            0
# pizza_ingredients     0
# Items_Qty_In_Grams    4
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# pizza_name_id         0
# pizza_name            0
# pizza_ingredients     0
# Items_Qty_In_Grams    0
# dtype: int64

# %%
pizza= pd.merge(data,df,on="pizza_name_id",how="inner")

# %%
pizza.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0         1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1         1         1     hawaiian_m         1 2015-01-01   11:38:36
# 2         2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 3         2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 4         2         2  classic_dlx_m         1 2015-01-01   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       13.25        13.25          M        Classic
# 2       16.00        16.00          M        Classic
# 3       16.00        16.00          M        Classic
# 4       16.00        16.00          M        Classic
#
#                                  pizza_ingredients_x  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1           Sliced Ham, Pineapple, Mozzarella Cheese
# 2  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 3  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 4  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
#
#                pizza_name_x  order_hour  order_day  order_month  order_week  \
# 0        The Hawaiian Pizza           0          1            1           1
# 1        The Hawaiian Pizza           0          1            1           1
# 2  The Classic Deluxe Pizza           0          1            1           1
# 3  The Classic Deluxe Pizza           0          1            1           1
# 4  The Classic Deluxe Pizza           0          1            1           1
#
#                pizza_name_y pizza_ingredients_y  Items_Qty_In_Grams
# 0        The Hawaiian Pizza           Pineapple                30.0
# 1        The Hawaiian Pizza   Mozzarella Cheese                20.0
# 2  The Classic Deluxe Pizza           Pepperoni                40.0
# 3  The Classic Deluxe Pizza           Mushrooms                40.0
# 4  The Classic Deluxe Pizza          Red Onions                40.0

# %%
#finding total sale per day

total_sales=data.groupby("order_date")["quantity"].sum().reset_index()

# %%
total_sales
# Out:
#     order_date  quantity
# 0   2015-01-01       156
# 1   2015-01-02       191
# 2   2015-01-03        99
# 3   2015-01-04       135
# 4   2015-01-05       154
# ..         ...       ...
# 353 2015-12-27        89
# 354 2015-12-28       102
# 355 2015-12-29        80
# 356 2015-12-30        82
# 357 2015-12-31       178
#
# [358 rows x 2 columns]

# %%
# DATA VISUALIZATION

# %%
# countplot for order for a week
plt.figure(figsize=(15,5))
sns.countplot(data=data,x=data["order_week"])
plt.show()

# %%
# countplot for monthly order
plt.figure(figsize=(15,5))
sns.countplot(data=data,x=data["order_month"])
plt.show()

# %%
data["pizza_name"].value_counts()
# Out:
# pizza_name
# The Classic Deluxe Pizza                      2416
# The Barbecue Chicken Pizza                    2368
# The Hawaiian Pizza                            2365
# The Pepperoni Pizza                           2364
# The Thai Chicken Pizza                        2313
# The California Chicken Pizza                  2299
# The Spicy Italian Pizza                       1884
# The Sicilian Pizza                            1884
# The Southwest Chicken Pizza                   1883
# The Italian Supreme Pizza                     1848
# The Four Cheese Pizza                         1847
# The Big Meat Pizza                            1810
# The Vegetables + Vegetables Pizza             1510
# The Mexicana Pizza                            1453
# The Napolitana Pizza                          1447
# The Spinach and Feta Pizza                    1430
# The Prosciutto and Arugula Pizza              1426
# The Pepper Salami Pizza                       1420
# The Italian Capocollo Pizza                   1412
# The Greek Pizza                               1404
# The Five Cheese Pizza                         1354
# The Pepperoni, Mushroom, and Peppers Pizza    1341
# The Green Garden Pizza                         985
# The Chicken Alfredo Pizza                      978
# The Italian Vegetables Pizza                   974
# The Chicken Pesto Pizza                        961
# The Soppressata Pizza                          956
# The Spinach Pesto Pizza                        954
# The Spinach Supreme Pizza                      939
# The Calabrese Pizza                            927
# The Mediterranean Pizza                        923
# The Brie Carre Pizza                           479
# Name: count, dtype: int64

# %%
# countplot for monthly order
plt.figure(figsize=(15,5))
sns.countplot(data=data,x="pizza_name",hue="pizza_size")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=total_sales,x="order_date",y="quantity")
plt.show()

# %% [markdown]
# # ML MODEL

# %%
#installing prophet

# !pip install prophet
# Out:
# Requirement already satisfied: prophet in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from prophet) (1.2.4)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from prophet) (2.1.3)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from prophet) (3.9.2)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from prophet) (2.2.3)
# Requirement already satisfied: holidays<1,>=0.25 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from prophet) (0.62)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib-resources in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from prophet) (6.4.5)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from matplotlib>=2.0.0->prophet) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from pandas>=1.0.4->prophet) (2024.2)
# Requirement already satisfied: colorama in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\gs0864\onedrive\desktop\for_vs_code\env\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#setting cuf-off data for split

total_sales.tail()
# Out:
#     order_date  quantity
# 353 2015-12-27        89
# 354 2015-12-28       102
# 355 2015-12-29        80
# 356 2015-12-30        82
# 357 2015-12-31       178

# %%
#Taking last two months as test data

cut_off= "2015-10-30"

# %%
#Renaming the columns to match the prophet

total_sales.rename(columns={"order_date":"ds","quantity":"y"},inplace=True)  #ds means data series whcih represent the date columm
                                                                                # y is target variable which is quantity

# %%
# splitting the data into train and test

train_data = total_sales[total_sales["ds"]<=cut_off]
test_data = total_sales[total_sales["ds"]>cut_off]

# %%
#initializing the model

model = Prophet()

# %%
#fit the model on train data
model.fit(train_data)
# Out:
# 14:34:40 - cmdstanpy - INFO - Chain [1] start processing
# 14:34:40 - cmdstanpy - INFO - Chain [1] done processing

# %%
#make future prediction for test data

future = model.make_future_dataframe(periods=len(test_data))  #here periods is size of test data which is 59 days
forecast = model.predict(future)

# %%
#predicted values for test period
predicted_test = forecast[forecast["ds"]>cut_off][["ds","yhat"]]

# %%
# actual value and predicted value
actual_value= test_data["y"].values
predicted_value =predicted_test["yhat"].values

# %%
test_data["y"].count()
# Out:
# np.int64(60)

# %%
train_data["y"].count()
# Out:
# np.int64(298)

# %%
mape= mean_absolute_percentage_error(actual_value,predicted_value)
print(f"mean_absolute_percentage_error:{mape}")
# Out:
# mean_absolute_percentage_error:0.15625010664253067

# %%
fig = model.plot_components(forecast)
plt.show()

# %% [markdown]
# # predicting future values

# %%
total_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358 entries, 0 to 357
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      358 non-null    datetime64[ns]
#  1   y       358 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.7 KB

# %%
model_1= Prophet(weekly_seasonality=True,changepoint_prior_scale=0.5,n_changepoints=50,changepoint_range=0.2)

# %%
model_1.add_seasonality(name='weekly', period=7, fourier_order=5)

# %%
model_1.fit(total_sales)
# Out:
# 14:34:40 - cmdstanpy - INFO - Chain [1] start processing
# 14:34:40 - cmdstanpy - INFO - Chain [1] done processing

# %%
#create a future dataframe for the next 7 days

future_1 = model_1.make_future_dataframe(periods=7)

# %%
#make prediction for the next 7 days

forecast_1 = model_1.predict(future_1)

# %%
predicted_sales=forecast_1[['ds', 'yhat']].tail(7)

# %%
predicted_sales
# Out:
#             ds        yhat
# 358 2016-01-01  155.018358
# 359 2016-01-02  140.732166
# 360 2016-01-03  119.398782
# 361 2016-01-04  131.772103
# 362 2016-01-05  132.526492
# 363 2016-01-06  133.739875
# 364 2016-01-07  142.915533

# %%
predicted=forecast_1[["ds","yhat"]]

# %%
predicted_value=forecast_1[["yhat"]].tail(7).values

# %%
actual_sales=total_sales.iloc[0:7]

# %%
actual_sales
# Out:
#           ds    y
# 0 2015-01-01  156
# 1 2015-01-02  191
# 2 2015-01-03   99
# 3 2015-01-04  135
# 4 2015-01-05  154
# 5 2015-01-06  184
# 6 2015-01-07  137

# %%
actual_value=actual_sales[["y"]].values

# %%
mape= np.mean((np.abs(actual_value-predicted_value)/actual_value))*100

# %%
print(f"Mean absolute percentage error:{mape:.2f}%")
# Out:
# Mean absolute percentage error:13.65%

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=actual_sales,x="ds",y="y")
sns.lineplot(data=predicted_sales,x="ds",y="yhat")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=total_sales,x="ds",y="y")
sns.lineplot(data=predicted,x="ds",y="yhat")
plt.show()

# %%
forecast_1 = model_1.predict(future_1)
fig = model_1.plot_components(forecast_1)

# %% [markdown]
# # Ingredient Calculation

# %%
pizza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264380 entries, 0 to 264379
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   pizza_id             264380 non-null  int64
#  1   order_id             264380 non-null  int64
#  2   pizza_name_id        264380 non-null  object
#  3   quantity             264380 non-null  int64
#  4   order_date           264380 non-null  datetime64[ns]
#  5   order_time           264380 non-null  object
#  6   unit_price           264380 non-null  float64
#  7   total_price          264380 non-null  float64
#  8   pizza_size           264380 non-null  object
#  9   pizza_category       264380 non-null  object
#  10  pizza_ingredients_x  264380 non-null  object
#  11  pizza_name_x         264380 non-null  object
#  12  order_hour           264380 non-null  int32
#  13  order_day            264380 non-null  int32
#  14  order_month          264380 non-null  int32
#  15  order_week           264380 non-null  UInt32
#  16  pizza_name_y         264380 non-null  object
#  17  pizza_ingredients_y  264380 non-null  object
#  18  Items_Qty_In_Grams   264380 non-null  float64
# dtypes: UInt32(1), datetime64[ns](1), float64(3), int32(3), int64(3), object(8)
# memory usage: 34.5+ MB

# %%
predicted_sales
# Out:
#             ds        yhat
# 358 2016-01-01  155.018358
# 359 2016-01-02  140.732166
# 360 2016-01-03  119.398782
# 361 2016-01-04  131.772103
# 362 2016-01-05  132.526492
# 363 2016-01-06  133.739875
# 364 2016-01-07  142.915533

# %%
#Initialize an empty list to hold ingredient requirements
ingredient_requirements = []

#loop through the predicted sales dataframe
for index, row in predicted_sales.iterrows():
    one_week = row["ds"]  #get the current date
    total_predicted_sales = int(row["yhat"])  #predicted sales for the day

    #loop through the ingredients dataframe
    for _, ingredient_row in df.iterrows():
        #calculate the total quantity needed for the week for each ingredient
        ingredient_qty = ingredient_row["Items_Qty_In_Grams"] * total_predicted_sales
        
        #append the ingredient requirements to the list
        ingredient_requirements.append({
            "Date": one_week,
            "Ingredient": ingredient_row["pizza_ingredients"],
            "Total Quantity Needed (grams)": ingredient_qty,
            "Items_Qty_In_Grams": ingredient_row["Items_Qty_In_Grams"],
            
        })

# Convert the list to a DataFrame
ingredient_requirements_df = pd.DataFrame(ingredient_requirements)

# Reset index for better readability
ingredient_requirements_df.reset_index(drop=True, inplace=True)

# %%
print(predicted_sales)
# Out:
#             ds        yhat
# 358 2016-01-01  155.018358
# 359 2016-01-02  140.732166
# 360 2016-01-03  119.398782
# 361 2016-01-04  131.772103
# 362 2016-01-05  132.526492
# 363 2016-01-06  133.739875
# 364 2016-01-07  142.915533

# %%
ingredient_requirements_df
# Out:
#            Date         Ingredient  Total Quantity Needed (grams)  \
# 0    2016-01-01  Barbecued Chicken                         6200.0
# 1    2016-01-01        Red Peppers                         2325.0
# 2    2016-01-01      Green Peppers                         3100.0
# 3    2016-01-01           Tomatoes                         4650.0
# 4    2016-01-01         Red Onions                         9300.0
# ...         ...                ...                            ...
# 3593 2016-01-07      Green Peppers                         2840.0
# 3594 2016-01-07         Red Onions                         2840.0
# 3595 2016-01-07           Zucchini                         1420.0
# 3596 2016-01-07            Spinach                         2130.0
# 3597 2016-01-07             Garlic                          710.0
#
#       Items_Qty_In_Grams
# 0                   40.0
# 1                   15.0
# 2                   20.0
# 3                   30.0
# 4                   60.0
# ...                  ...
# 3593                20.0
# 3594                20.0
# 3595                10.0
# 3596                15.0
# 3597                 5.0
#
# [3598 rows x 4 columns]

# %%
ingredient_requirements_df.duplicated().sum()
# Out:
# np.int64(2366)

# %%
ingredient_requirements_df.drop_duplicates(subset=["Date","Ingredient","Total Quantity Needed (grams)","Items_Qty_In_Grams"],inplace=True)

# %%
ingredient_requirements_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
ingredient_requirements_df
# Out:
#            Date         Ingredient  Total Quantity Needed (grams)  \
# 0    2016-01-01  Barbecued Chicken                         6200.0
# 1    2016-01-01        Red Peppers                         2325.0
# 2    2016-01-01      Green Peppers                         3100.0
# 3    2016-01-01           Tomatoes                         4650.0
# 4    2016-01-01         Red Onions                         9300.0
# ...         ...                ...                            ...
# 3569 2016-01-07        Feta Cheese                        11360.0
# 3570 2016-01-07           Tomatoes                         7100.0
# 3571 2016-01-07             Garlic                         3550.0
# 3572 2016-01-07   Beef Chuck Roast                        28400.0
# 3573 2016-01-07         Red Onions                        14200.0
#
#       Items_Qty_In_Grams
# 0                   40.0
# 1                   15.0
# 2                   20.0
# 3                   30.0
# 4                   60.0
# ...                  ...
# 3569                80.0
# 3570                50.0
# 3571                25.0
# 3572               200.0
# 3573               100.0
#
# [1232 rows x 4 columns]

# %%
ingredient_requirements_df.reset_index(drop=True, inplace=True)

# %%
ingredient_requirements_df
# Out:
#            Date         Ingredient  Total Quantity Needed (grams)  \
# 0    2016-01-01  Barbecued Chicken                         6200.0
# 1    2016-01-01        Red Peppers                         2325.0
# 2    2016-01-01      Green Peppers                         3100.0
# 3    2016-01-01           Tomatoes                         4650.0
# 4    2016-01-01         Red Onions                         9300.0
# ...         ...                ...                            ...
# 1227 2016-01-07        Feta Cheese                        11360.0
# 1228 2016-01-07           Tomatoes                         7100.0
# 1229 2016-01-07             Garlic                         3550.0
# 1230 2016-01-07   Beef Chuck Roast                        28400.0
# 1231 2016-01-07         Red Onions                        14200.0
#
#       Items_Qty_In_Grams
# 0                   40.0
# 1                   15.0
# 2                   20.0
# 3                   30.0
# 4                   60.0
# ...                  ...
# 1227                80.0
# 1228                50.0
# 1229                25.0
# 1230               200.0
# 1231               100.0
#
# [1232 rows x 4 columns]

# %%
# #group by pizza_name and count unique ingredients per pizza
# ingredient_count_per_pizza=df.groupby("pizza_name")["pizza_ingredients"].nunique()

# #print the average
# print(ingredient_count_per_pizza.mean())

# %%
# df["pizza_name"].nunique()

# %%
# 32*5.59

# %%
# 178.88 *7

# %% [markdown]
# # PURCHASE ORDER

# %%
purchase_order = ingredient_requirements_df.copy()

# %%
purchase_order["Items_Qty_In_Grams"] = "Grams"

# %%
#renaming the columns
purchase_order.rename(columns={"Items_Qty_In_Grams":"Units"}, inplace=True)
purchase_order.rename(columns={"Total Quantity Needed (grams)":"Total Quantity Required"}, inplace=True)
purchase_order.rename(columns={"Total Quantity Required":"Ingredient Usage"}, inplace=True)

# %%
purchase_order =purchase_order[["Ingredient","Ingredient Usage","Units","Date"]]

# %%
purchase_order.head()
# Out:
#           Ingredient  Ingredient Usage  Units       Date
# 0  Barbecued Chicken            6200.0  Grams 2016-01-01
# 1        Red Peppers            2325.0  Grams 2016-01-01
# 2      Green Peppers            3100.0  Grams 2016-01-01
# 3           Tomatoes            4650.0  Grams 2016-01-01
# 4         Red Onions            9300.0  Grams 2016-01-01

# %%
#save the purchase order to an excel file
purchase_order.to_excel("purchase_order.xlsx", index=False)
